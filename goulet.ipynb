# %%
import seaborn as sns
iris = sns.load_dataset('iris')
# Out:
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-1-e8d59d239c8e> in <module>()
# ----> 1 import seaborn as sns
#       2 iris = sns.load_dataset('iris')
#
# C:\Users\elvislap\Miniconda2\envs\lib\site-packages\seaborn\__init__.py in <module>()
#       4
#       5 # Import seaborn objects
# ----> 6 from .rcmod import *
#       7 from .utils import *
#       8 from .palettes import *
#
# C:\Users\elvislap\Miniconda2\envs\lib\site-packages\seaborn\rcmod.py in <module>()
#       6 import matplotlib as mpl
#       7
# ----> 8 from . import palettes, _orig_rc_params
#       9
#      10
#
# C:\Users\elvislap\Miniconda2\envs\lib\site-packages\seaborn\palettes.py in <module>()
#      10 from .external.six.moves import range
#      11
# ---> 12 from .utils import desaturate, set_hls_values, get_color_cycle
#      13 from .xkcd_rgb import xkcd_rgb
#      14 from .crayons import crayons
#
# C:\Users\elvislap\Miniconda2\envs\lib\site-packages\seaborn\utils.py in <module>()
# ...
